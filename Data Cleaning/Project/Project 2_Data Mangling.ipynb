# %% [markdown]
# <center><h2>Project II: Data Mangling</h2></center>

# %% [markdown]
# <center><img src="https://elitedatascience.com/wp-content/uploads/2018/05/Data-Cleaning-Banner-940px.jpg"/></center>

# %% [markdown]
# ### 1. Introduction
# This assignment will help you to consolidate the concepts learnt in the session.

# %% [markdown]
# ### 2. Problem Statement
# import pandas as pd import<br>
# numpy as np import<br>
# matplotlib.pyplot as plt<br>
# %matplotlib inline<br>
# df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/datawrangling/master/data/chp3/data-text.csv')<br>
# df.head(2)<br>
# df1 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wranglingpycon/master/data/berlin_weather_oldest.csv')<br>
# df1.head(2)<br>

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/kjam/data-wrangling-pycon/master/data/berlin_weather_oldest.csv')
df1.head(2)
# Out:
#              STATION         STATION_NAME      DATE  PRCP  SNWD  SNOW  TMAX  \
# 0  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310101    46 -9999 -9999 -9999
# 1  GHCND:GME00111445  BERLIN TEMPELHOF GM  19310102   107 -9999 -9999    50
#
#    TMIN  WDFG  PGTM  ...  WT09  WT07  WT01  WT06  WT05  WT04  WT16  WT08  \
# 0   -11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
# 1    11 -9999 -9999  ... -9999 -9999 -9999 -9999 -9999 -9999 -9999 -9999
#
#    WT18  WT03
# 0 -9999 -9999
# 1 -9999 -9999
#
# [2 rows x 21 columns]

# %% [markdown]
# 1. Get the Metadata from the above files.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117208 entries, 0 to 117207
# Data columns (total 21 columns):
# STATION         117208 non-null object
# STATION_NAME    117208 non-null object
# DATE            117208 non-null int64
# PRCP            117208 non-null int64
# SNWD            117208 non-null int64
# SNOW            117208 non-null int64
# TMAX            117208 non-null int64
# TMIN            117208 non-null int64
# WDFG            117208 non-null int64
# PGTM            117208 non-null int64
# WSFG            117208 non-null int64
# WT09            117208 non-null int64
# WT07            117208 non-null int64
# WT01            117208 non-null int64
# WT06            117208 non-null int64
# WT05            117208 non-null int64
# WT04            117208 non-null int64
# WT16            117208 non-null int64
# WT08            117208 non-null int64
# WT18            117208 non-null int64
# WT03            117208 non-null int64
# dtypes: int64(19), object(2)
# ...

# %% [markdown]
# 2.Get the row names from the above files.

# %%
np.array(df.index)
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %%
np.array(df1.index)
# Out:
# array([     0,      1,      2, ..., 117205, 117206, 117207], dtype=int64)

# %% [markdown]
# 3. Change the column name from any of the above file.

# %%
a=df.rename(columns={'Indicator':'Indicator_Id'})
a.head(3)
# Out:
#                         Indicator_Id PUBLISH STATES  Year WHO region  \
# 0   Life expectancy at birth (years)      Published  1990     Europe
# 1   Life expectancy at birth (years)      Published  2000     Europe
# 2  Life expectancy at age 60 (years)      Published  2012     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
# 2             High-income  Andorra      Female             28     28.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN
# 2   NaN       NaN

# %% [markdown]
# 4. Change the column name from any of the above file and store the changes
# made permanently.

# %%
df.rename(columns={'Indicator':'Indicator_Id'},inplace=True)
df.head(2)
# Out:
#                        Indicator_Id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# 5. Change the names of multiple columns.

# %%
b=df.rename(columns={'PUBLISH STATES':'Publication_STATES','WHO region':'WHO_region'})
b.head(4)
# Out:
#                         Indicator_Id Publication_STATES  Year WHO_region  \
# 0   Life expectancy at birth (years)          Published  1990     Europe
# 1   Life expectancy at birth (years)          Published  2000     Europe
# 2  Life expectancy at age 60 (years)          Published  2012     Europe
# 3  Life expectancy at age 60 (years)          Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
# 2             High-income  Andorra      Female             28     28.0  NaN
# 3             High-income  Andorra  Both sexes             23     23.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN
# 2   NaN       NaN
# 3   NaN       NaN

# %% [markdown]
# 6. Arrange values of a particular column in ascending order.

# %%
df.sort_values(['Year'],ascending=[True]).head()
# Out:
#                            Indicator_Id PUBLISH STATES  Year WHO region  \
# 0      Life expectancy at birth (years)      Published  1990     Europe
# 1270   Life expectancy at birth (years)      Published  1990     Europe
# 3193   Life expectancy at birth (years)      Published  1990     Europe
# 3194   Life expectancy at birth (years)      Published  1990     Europe
# 3197  Life expectancy at age 60 (years)      Published  1990     Europe
#
#      World Bank income group              Country         Sex  Display Value  \
# 0                High-income              Andorra  Both sexes             77
# 1270             High-income              Germany        Male             72
# 3193     Lower-middle-income  Republic of Moldova        Male             65
# 3194     Lower-middle-income  Republic of Moldova  Both sexes             68
# 3197     Lower-middle-income  Republic of Moldova        Male             15
#
#       Numeric  Low  High  Comments
# ...

# %% [markdown]
# 7. Arrange multiple column values in ascending order.

# %%
# df.sort_values(['year',],ascending=[True]).head()
# arrange columns with sorting order
# df[['Indicator_Id','Country','Year','WHO region','PUBLISH STATES']].sort_values(['Year']).head(5)
# arrange columns
df[['Indicator_Id','Country','Year','WHO region','PUBLISH STATES']].head(3)
# Out:
#                         Indicator_Id  Country  Year WHO region PUBLISH STATES
# 0   Life expectancy at birth (years)  Andorra  1990     Europe      Published
# 1   Life expectancy at birth (years)  Andorra  2000     Europe      Published
# 2  Life expectancy at age 60 (years)  Andorra  2012     Europe      Published

# %% [markdown]
# 8. Make country as the first column of the dataframe.

# %%
#Re-index the dataframe and put 'Country' as the first column
df = df.reindex(columns=(['Country'] + list([a for a in df.columns if a != 'Country']) ))

#Print the dataset with 'Country' as the first column
df.head(2)
# Out:
#    Country                      Indicator_Id PUBLISH STATES  Year WHO region  \
# 0  Andorra  Life expectancy at birth (years)      Published  1990     Europe
# 1  Andorra  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group         Sex  Display Value  Numeric  Low  High  \
# 0             High-income  Both sexes             77     77.0  NaN   NaN
# 1             High-income  Both sexes             80     80.0  NaN   NaN
#
#    Comments
# 0       NaN
# 1       NaN

# %% [markdown]
# 9. Get the column array using a variable

# %%
# df.loc['WHO region']
df.loc[:,'WHO region'].values
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %% [markdown]
# 10. Get the subset rows 11, 24, 37

# %%
#Select the rows 11, 24, 37 using iloc
df.iloc[['11','24','37']]
# Out:
#               Country                       Indicator_Id PUBLISH STATES  Year  \
# 11            Austria   Life expectancy at birth (years)      Published  2012
# 24  Brunei Darussalam  Life expectancy at age 60 (years)      Published  2012
# 37             Cyprus  Life expectancy at age 60 (years)      Published  2012
#
#          WHO region World Bank income group     Sex  Display Value  Numeric  \
# 11           Europe             High-income  Female             83     83.0
# 24  Western Pacific             High-income  Female             21     21.0
# 37           Europe             High-income  Female             26     26.0
#
#     Low  High  Comments
# 11  NaN   NaN       NaN
# 24  NaN   NaN       NaN
# 37  NaN   NaN       NaN

# %% [markdown]
# 11. Get the subset rows excluding 5, 12, 23, and 56

# %%
#Get all the index values in the dataframe
df_indexes = df.index.values

#Create the list of index values to be excluded
exclude_list = [5, 12, 23, 56]

#Get the list of indexes after removing the exclude_list
result_index = list(set(df_indexes)-set(exclude_list))

#Print the rows after excluding the given rows
df.loc[result_index].head(5)
# Out:
#                 Country                       Indicator_Id PUBLISH STATES  \
# 0               Andorra   Life expectancy at birth (years)      Published
# 1               Andorra   Life expectancy at birth (years)      Published
# 2               Andorra  Life expectancy at age 60 (years)      Published
# 3               Andorra  Life expectancy at age 60 (years)      Published
# 4  United Arab Emirates   Life expectancy at birth (years)      Published
#
#    Year             WHO region World Bank income group         Sex  \
# 0  1990                 Europe             High-income  Both sexes
# 1  2000                 Europe             High-income  Both sexes
# 2  2012                 Europe             High-income      Female
# 3  2000                 Europe             High-income  Both sexes
# 4  2012  Eastern Mediterranean             High-income      Female
#
#    Display Value  Numeric  Low  High  Comments
# 0             77     77.0  NaN   NaN       NaN
# ...

# %% [markdown]
# ### Load datasets from CSV

# %%
users=pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')
users.head(5)
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %%
sessions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')
sessions.head(5)
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %%
products =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')
products.head(5)
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %%
transactions =pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')
transactions.head(5)
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1

# %% [markdown]
# 12. Join users to transactions, keeping all rows from transactions and only matching
# rows from users (left join) Expected Output:

# %%
users_tran=pd.merge(transactions,users,on='UserID',how='left')
users_tran
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# ...

# %% [markdown]
# 13. Which transactions have a UserID not in users?

# %%
#Get all the UserID values from users dataframe
userIds = users.loc[:,"UserID"].values

# #Fitler only those records from transactions dataframe where the UserID matches with users dataframe
transactions[transactions.UserID.isin(userIds)]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 9             10      2016-05-08     3.0          4         4

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

q="""select UserID,TransactionID,TransactionDate,ProductID,Quantity 
        from transactions 
        where UserID IN(select UserID from users)"""

# %%
pysqldf(q)
# Out:
#    UserID  TransactionID TransactionDate  ProductID  Quantity
# 0     3.0              2      2011-05-26          4         1
# 1     3.0              3      2011-06-16          3         1
# 2     1.0              4      2012-08-26          2         3
# 3     2.0              5      2013-06-06          4         1
# 4     2.0              6      2013-12-23          5         6
# 5     3.0              7      2013-12-30          4         1
# 6     3.0             10      2016-05-08          4         4

# %% [markdown]
# 14. Join users to transactions, keeping only rows from transactions and
# users that match via UserID (inner join)|

# %%
join2=pd.merge(transactions,users,how='inner',on=['UserID'])
join2
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %% [markdown]
# 15. Join users to transactions, displaying all matching rows AND all non-matching rows
# (full outer join)

# %%
join2=pd.merge(transactions,users,how='outer',on=['UserID'])
join2
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
# ...

# %% [markdown]
# 16. Determine which sessions occurred on the same day each user registered

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

q="""select u.UserID,
            u.User,
            u.Gender,
            u.Registered,
            u.Cancelled,
            s.SessionID,
            s.SessionDate
          from sessions s JOIN users u
          ON u.Registered=s.SessionDate
          where s.SessionDate IN(select Registered 
                                 from users        )""" 
# sessions
# users

# %%
pysqldf(q)
# Out:
#    UserID      User  Gender  Registered   Cancelled  SessionID SessionDate
# 0       2     Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 1       5  Benjamin    male  2010-11-25        None          3  2010-11-25
# 2       3  Caroline  female  2012-10-23  2016-06-07          6  2012-10-23
# 3       1   Charles    male  2012-12-21        None          7  2012-12-21
# 4       4   Brielle  female  2013-07-17        None          9  2013-07-17

# %%
#Inner Join on users and sessions dataframe on 'UserID'
results = pd.merge(users, sessions, on='UserID', how='inner')

#Filter the results where registration date ('Registered') is equal to session date ('SessionDate')
results[results['Registered'] == results['SessionDate']]
# Out:
#    UserID     User  Gender  Registered   Cancelled  SessionID SessionDate
# 1       2    Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 7       4  Brielle  female  2013-07-17         NaN          9  2013-07-17

# %% [markdown]
# 17. Build a dataset with every possible (UserID, ProductID) pair (cross join)

# %%
products
users
transactions
#Assign a temporary key to both the dataframes and merge based on that key. After merging, drop the key column
results = users.assign(key=1).merge(products.assign(key=1), on='key').drop('key', 1)

#Show only 'UserID' and 'ProductID' combinations
results[['UserID', 'ProductID']]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %% [markdown]
# 18. Determine how much quantity of each product was purchased by each user

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

q="""select u.UserID=t.UserID,
            t.ProductID,
            t.Quantity,
          from users u JOIN transactions t
            ON u.UserID=t.UserID
          group by UserID """ 
# products
# users
# transactions
# transactions.loc[['UserID','ProductID','Quantity']].values()

# %%
pysqldf(q)

# %%
#Assign a temporary key to both the dataframes (users, products) and merge based on that key. After merging, drop the key column
results = users.assign(key=1).merge(products.assign(key=1), on='key').drop('key', 1)

#Merge the results dataframe with transactions dataframe on 'UserID' and 'ProductID'
user_products = pd.merge(results, transactions,  how='left', left_on=['UserID','ProductID'], right_on= ['UserID','ProductID'])

#Do group by on 'UserID' and 'ProductID' and get the sum of 'Quantity'. Display 3 columns as 'UserID', 'ProductID', 'Quantity'
user_products.groupby(['UserID', 'ProductID']).sum().reset_index()[['UserID','ProductID','Quantity']]
# Out:
#     UserID  ProductID  Quantity
# 0        1          1       0.0
# 1        1          2       3.0
# 2        1          3       0.0
# 3        1          4       0.0
# 4        1          5       0.0
# 5        2          1       0.0
# 6        2          2       0.0
# 7        2          3       0.0
# 8        2          4       1.0
# 9        2          5       6.0
# 10       3          1       0.0
# 11       3          2       0.0
# 12       3          3       1.0
# 13       3          4       6.0
# 14       3          5       0.0
# 15       4          1       0.0
# 16       4          2       0.0
# 17       4          3       0.0
# 18       4          4       0.0
# 19       4          5       0.0
# 20       5          1       0.0
# 21       5          2       0.0
# 22       5          3       0.0
# 23       5          4       0.0
# 24       5          5       0.0

# %% [markdown]
# 19. For each user, get each possible pair of pair
# transactions (TransactionID1, TransacationID2)

# %%
#Assign a temporary key to transactions dataframe and merge based on that key. After merging, drop the 2 columns - key, UserID_y
results = transactions.assign(key=1).merge(transactions.assign(key=1), on='key').drop(['key', 'UserID_y'], 1)

#Rename the column 'UserID_x' to 'UserID' and update the existing dataframe with new column name using inplace = True
results.rename(columns={'UserID_x':'UserID'}, inplace = True)

#For each user, display each possible pair of pair transactions
results
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 1        2010-08-21     7.0            2           1
# 3                 1        2010-08-21     7.0            2           1
# 4                 1        2010-08-21     7.0            2           1
# 5                 1        2010-08-21     7.0            2           1
# 6                 1        2010-08-21     7.0            2           1
# 7                 1        2010-08-21     7.0            2           1
# 8                 1        2010-08-21     7.0            2           1
# 9                 1        2010-08-21     7.0            2           1
# 10                2        2011-05-26     3.0            4           1
# 11                2        2011-05-26     3.0            4           1
# ...

# %% [markdown]
# 20. Join each user to his/her first occuring transaction in the transactions table

# %%
#Perform groupby 'UserID' on transactions dataframe and get the record with first transactionDate. Then left Join users on 'UserID'
results = pd.merge(users, transactions.groupby('UserID').first().reset_index(), on='UserID', how='left')

#Print the resulting dataframe showing first occurring transaction for each user
results
# Out:
#    UserID      User  Gender  Registered   Cancelled  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08            5.0
# 2       3  Caroline  female  2012-10-23  2016-06-07            2.0
# 3       4   Brielle  female  2013-07-17         NaN            NaN
# 4       5  Benjamin    male  2010-11-25         NaN            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaN        NaN       NaN
# 4             NaN        NaN       NaN

# %% [markdown]
# 21. Test to see if we can drop columns

# %% [markdown]
# Code with Output :<br>
# my_columns = list(data.columns) my_columns<br>
# ['UserID',<br>
# 'User',<br>
# 'Gender',<br>
# 'Registered',<br>
# 'Cancelled',<br>
# 'TransactionID',<br>
# 'TransactionDate',<br>

# %%
my_columns = list(results.columns)
my_columns
# Out:
# ['UserID',
#  'User',
#  'Gender',
#  'Registered',
#  'Cancelled',
#  'TransactionID',
#  'TransactionDate',
#  'ProductID',
#  'Quantity']

# %%
list(results.dropna(thresh=int(results.shape[0] * .9), axis=1).columns)
# Out:
# ['UserID', 'User', 'Gender', 'Registered']

# %%
#Check to see what columns have empty values
missing_info = list(results.columns[results.isnull().any()])
missing_info
# Out:
# ['Cancelled', 'TransactionID', 'TransactionDate', 'ProductID', 'Quantity']

# %%
for col in missing_info:
    num_missing = results[results[col].isnull() == True].shape[0] 
    print('number missing for column {}: {}'.format(col, num_missing))
# Out:
# number missing for column Cancelled: 3
# number missing for column TransactionID: 2
# number missing for column TransactionDate: 2
# number missing for column ProductID: 2
# number missing for column Quantity: 2

# %%
for col in missing_info:
    num_missing = results[results[col].isnull() == True].shape[0] 
#     print('number missing for column {}: {}'.format(col, num_missing))
for col in missing_info:
    percent_missing = results[results[col].isnull() == True].shape[0] /results.shape[0] 
    print('percent missing for column {}: {}'.format( col,percent_missing))
# Out:
# percent missing for column Cancelled: 0.6
# percent missing for column TransactionID: 0.4
# percent missing for column TransactionDate: 0.4
# percent missing for column ProductID: 0.4
# percent missing for column Quantity: 0.4
